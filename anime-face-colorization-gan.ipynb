# %%
# %matplotlib inline

import numpy as np
import pandas as pd 
from skimage import io, color
import matplotlib.pyplot as plt
import cv2
import numpy as np

import os
PATH = "../input/data/data/"

# %% [markdown]
# **UTILS**

# %%
def display(img):
    plt.figure()
    plt.set_cmap('gray')
    plt.imshow(img)
    plt.show()


def combineLAB(l, a, b):
    shape = (l.shape[0], l.shape[1], 3)
    zeros = np.zeros(shape)
    zeros[:, :, 0] = l
    zeros[:, :, 1] = a
    zeros[:, :, 2] = b
    return zeros


def combineAB(a, b):
    shape = (a.shape[0], b.shape[1], 2)
    zeros = np.zeros(shape)
    zeros[:, :, 0] = a
    zeros[:, :, 1] = b
    return zeros


def combineL_AB(l, ab):
    shape = (l.shape[0], l.shape[1], 3)
    zeros = np.zeros(shape)
    zeros[:, :, 0] = l
    zeros[:, :, 1] = ab[:, :, 0]
    zeros[:, :, 2] = ab[:, :, 1]
    return zeros


def make3channels(gray):
    shape = (gray.shape[0], gray.shape[1], 3)
    zeros = np.zeros(shape)
    zeros[:, :, 0] = gray
    zeros[:, :, 1] = gray
    zeros[:, :, 2] = gray
    return zeros


def get_l_from_gray(img_path):
    img = io.imread(img_path)
    gray = color.rgb2gray(img)
    gray = make3channels(gray)
    lgray = color.rgb2lab(gray, illuminant='D50')[:, :, 0]
    return lgray


def get_ab_from_file(file):
    img = io.imread(file)
    ab = np.zeros((64, 64, 2))
    ab[:, :, 0] = img[:, :, 1]
    ab[:, :, 1] = img[:, :, 2]
    return ab


def lab_normal_image(path):
    l, ab = load_img_for_training(path)
    l, ab = (l-127.5)/127.5, (ab-127.5)/127.5
    return l, ab


def rgb_image(l, ab):
    l, ab = l*127.5 + 127.5, (ab*127.5)+127.5
    lab = combineL_AB(l, ab)
    rgb = color.lab2rgb(lab, illuminant='D50')
    return rgb


def load_img_for_training(img_path):
    img = io.imread(img_path)
    lab = color.rgb2lab(img, illuminant='D50')
    l, a, b = lab[:, :, 0], lab[:, :, 1], lab[:, :, 2]
    ab = combineAB(a, b)
    lgray = get_l_from_gray(img_path)
    return lgray, ab


def save_ab_file(image, filepath):
    # add in 0zeros to its first component
    shape = (image.shape[0], image.shape[1], 3)
    new_ab_image = np.zeros(shape)
    new_ab_image[:, :, 1] = image[:, :, 0]
    new_ab_image[:, :, 2] = image[:, :, 1]
    save_file(new_ab_image, filepath)


def save_file(image, filepath):
    io.imsave(filepath, image)


def load_ab_image(path):
    img = io.imread(path)
    shape = (img.shape[0], img.shape[1], 2)
    ab = np.zeros(shape)
    ab[:, :, 0] = img[:, :, 1]
    ab[:, :, 1] = img[:, :, 2]
    return ab

# %% [markdown]
# **Data Loading**

# %%
def get_data(path):
    start = 1
    end = 18000

    x_data = np.zeros((18000, 64, 64))
    y_data = np.zeros((18000, 64, 64, 2))

    for i in range(start, end+1):
        filename = path + str(i) + ".png"
        l, ab = lab_normal_image(filename)
        x_data[i-1] = l
        y_data[i-1] = ab

    return x_data, y_data

x_data,y_data = get_data(PATH)
print("X SHAPE:",x_data.shape)
print("Y SHAPE:",y_data.shape)
# Out:
# X SHAPE: (18000, 64, 64)
# Y SHAPE: (18000, 64, 64, 2)

# %%
l_sample,ab_sample = x_data[3],y_data[3]
rgb_sample = rgb_image(l_sample,ab_sample)
display(rgb_sample)
display(l_sample)

# %% [markdown]
# **GAN Architecture**

# %%
from keras import *
from keras.layers import *
from keras.activations import *
from keras.optimizers import *
from matplotlib import pyplot as plt
from utils import *
from keras.initializers import RandomNormal, Zeros
# Out:
# Using TensorFlow backend.

# %%
def residual_block(feature, dropout=False):
    x = Conv2D(256, kernel_size=3, strides=1, padding='same', kernel_initializer=RandomNormal(
        mean=0.0, stddev=0.02), bias_initializer=Zeros())(feature)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    if dropout:
        x = Dropout(0.5)(x)
    x = Conv2D(256, kernel_size=3, strides=1, padding='same', kernel_initializer=RandomNormal(
        mean=0.0, stddev=0.02), bias_initializer=Zeros())(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return Add()([feature, x])


def conv_block(feature, out_channel, downsample=True, dropout=False):
    if downsample:
        x = Conv2D(out_channel, kernel_size=4, strides=2, padding='same', kernel_initializer=RandomNormal(
            mean=0.0, stddev=0.02), bias_initializer=Zeros())(feature)
    else:
        x = Conv2DTranspose(out_channel, kernel_size=4, strides=2, padding='same', kernel_initializer=RandomNormal(
            mean=0.0, stddev=0.02), bias_initializer=Zeros())(feature)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    if dropout:
        x = Dropout(0.5)(x)
    return x


def build_model(n_block=5):
    image_size = 64
    input_channel = 1
    output_channel = 2
    input = Input(shape=(image_size, image_size, input_channel))
    x = Conv2D(64, kernel_size=7, padding='same', kernel_initializer=RandomNormal(
        mean=0.0, stddev=0.02), bias_initializer=Zeros())(input)  # use reflection padding instead
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # downsample
    x = Conv2D(128, kernel_size=3, strides=2, padding='same', kernel_initializer=RandomNormal(
        mean=0.0, stddev=0.02), bias_initializer=Zeros())(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # downsample
    x = Conv2D(256, kernel_size=3, strides=2, padding='same', kernel_initializer=RandomNormal(
        mean=0.0, stddev=0.02), bias_initializer=Zeros())(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    for i in range(n_block):
        x = residual_block(x)
    # upsample
    x = Conv2DTranspose(128, kernel_size=3, strides=2, padding='same',
                        kernel_initializer=RandomNormal(mean=0.0, stddev=0.02), bias_initializer=Zeros())(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # upsample
    x = Conv2DTranspose(64, kernel_size=3, strides=2, padding='same', kernel_initializer=RandomNormal(
        mean=0.0, stddev=0.02), bias_initializer=Zeros())(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # out
    x = Conv2D(output_channel, kernel_size=7, padding='same', kernel_initializer=RandomNormal(
        mean=0.0, stddev=0.02), bias_initializer=Zeros())(x)  # use reflection padding instead
    x = BatchNormalization()(x)
    x = Activation('tanh')(x)
    model = Model(inputs=input, outputs=x)
    model.summary()
    return model

def save_images(generator, samples):
    ab_values = generator.predict(samples)
    plt.figure()
    plt.set_cmap('gray')
    for i in range(ab_values.shape[0]):
        l_val = samples[i][:,:,0]
        ab_val = ab_values[i]
        rgb = rgb_image(l_val, ab_val)
        if i == 0:
            display(rgb)
        ax = plt.subplot(4, 4, i+1)
        im = ax.imshow(rgb)
        plt.tight_layout()
        plt.title(i)
    plt.show()
    plt.savefig('gan_generated_image.png')


    
def train_network(x_data,y_data,epochs=100, batch_size=128, save_interval=5):
    input_shape = (64, 64, 1)
    output_shape = (64, 64, 2)
    model = build_model()
    model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae'])
    model.fit(x_data,y_data,validation_split=0.33,epochs=epochs,batch_size=128,)
    model.save('model.h5')
    print("MODEL SAVED")
    return model

# %%
x_data = x_data.reshape((18000,64,64,1))
model=train_network(x_data,y_data,epochs=200)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 64)   3200        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 128)  73856       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 256)  295168      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 256)  590080      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 256)  590080      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 256)  0           activation_3[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  590080      add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 256)  0           add_1[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 256)  590080      add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  590080      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 256)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 256)  0           add_2[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 256)  590080      add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 256)  0           add_3[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 256)  590080      add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 256)  590080      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 256)  0           add_4[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 128)  295040      add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 128)  512         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 64)   73792       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64)   256         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 2)    6274        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 2)    8           conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 2)    0           batch_normalization_16[0][0]
# ==================================================================================================
# Total params: 6,660,938
# Trainable params: 6,654,534
# Non-trainable params: 6,404
# __________________________________________________________________________________________________
# Train on 12059 samples, validate on 5941 samples
# Epoch 1/200
# 12059/12059 [==============================] - 27s 2ms/step - loss: 0.7729 - mean_squared_error: 0.7729 - mean_absolute_error: 0.8194 - val_loss: 0.5317 - val_mean_squared_error: 0.5317 - val_mean_absolute_error: 0.7119
# Epoch 2/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.5926 - mean_squared_error: 0.5926 - mean_absolute_error: 0.7142 - val_loss: 0.3968 - val_mean_squared_error: 0.3968 - val_mean_absolute_error: 0.6093
# Epoch 3/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.4818 - mean_squared_error: 0.4818 - mean_absolute_error: 0.6374 - val_loss: 1.3573 - val_mean_squared_error: 1.3573 - val_mean_absolute_error: 0.9565
# Epoch 4/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.4022 - mean_squared_error: 0.4022 - mean_absolute_error: 0.5771 - val_loss: 1.6307 - val_mean_squared_error: 1.6307 - val_mean_absolute_error: 1.0297
# Epoch 5/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.3379 - mean_squared_error: 0.3379 - mean_absolute_error: 0.5274 - val_loss: 0.2313 - val_mean_squared_error: 0.2313 - val_mean_absolute_error: 0.4466
# Epoch 6/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.2899 - mean_squared_error: 0.2899 - mean_absolute_error: 0.4876 - val_loss: 0.2622 - val_mean_squared_error: 0.2622 - val_mean_absolute_error: 0.4213
# Epoch 7/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.2457 - mean_squared_error: 0.2457 - mean_absolute_error: 0.4453 - val_loss: 0.2222 - val_mean_squared_error: 0.2222 - val_mean_absolute_error: 0.4062
# Epoch 8/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.2118 - mean_squared_error: 0.2118 - mean_absolute_error: 0.4119 - val_loss: 0.2565 - val_mean_squared_error: 0.2565 - val_mean_absolute_error: 0.3876
# Epoch 9/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.1847 - mean_squared_error: 0.1847 - mean_absolute_error: 0.3832 - val_loss: 0.1513 - val_mean_squared_error: 0.1513 - val_mean_absolute_error: 0.3347
# Epoch 10/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.1658 - mean_squared_error: 0.1658 - mean_absolute_error: 0.3614 - val_loss: 2.8314 - val_mean_squared_error: 2.8314 - val_mean_absolute_error: 1.4965
# Epoch 11/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.1440 - mean_squared_error: 0.1440 - mean_absolute_error: 0.3372 - val_loss: 1.5941 - val_mean_squared_error: 1.5941 - val_mean_absolute_error: 0.9551
# Epoch 12/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.1271 - mean_squared_error: 0.1271 - mean_absolute_error: 0.3175 - val_loss: 0.1012 - val_mean_squared_error: 0.1012 - val_mean_absolute_error: 0.2938
# Epoch 13/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.1141 - mean_squared_error: 0.1141 - mean_absolute_error: 0.2982 - val_loss: 0.0835 - val_mean_squared_error: 0.0835 - val_mean_absolute_error: 0.2619
# Epoch 14/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.1019 - mean_squared_error: 0.1019 - mean_absolute_error: 0.2815 - val_loss: 0.1014 - val_mean_squared_error: 0.1014 - val_mean_absolute_error: 0.2630
# Epoch 15/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0919 - mean_squared_error: 0.0919 - mean_absolute_error: 0.2658 - val_loss: 0.0808 - val_mean_squared_error: 0.0808 - val_mean_absolute_error: 0.2458
# Epoch 16/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0833 - mean_squared_error: 0.0833 - mean_absolute_error: 0.2541 - val_loss: 0.1512 - val_mean_squared_error: 0.1512 - val_mean_absolute_error: 0.2788
# Epoch 17/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.1233 - mean_squared_error: 0.1233 - mean_absolute_error: 0.2557 - val_loss: 3.7637 - val_mean_squared_error: 3.7637 - val_mean_absolute_error: 1.8920
# Epoch 18/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.1011 - mean_squared_error: 0.1011 - mean_absolute_error: 0.2304 - val_loss: 0.0843 - val_mean_squared_error: 0.0843 - val_mean_absolute_error: 0.2083
# Epoch 19/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0737 - mean_squared_error: 0.0737 - mean_absolute_error: 0.2228 - val_loss: 0.4922 - val_mean_squared_error: 0.4922 - val_mean_absolute_error: 0.3866
# Epoch 20/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0662 - mean_squared_error: 0.0662 - mean_absolute_error: 0.2135 - val_loss: 0.0559 - val_mean_squared_error: 0.0559 - val_mean_absolute_error: 0.1874
# Epoch 21/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0573 - mean_squared_error: 0.0573 - mean_absolute_error: 0.2070 - val_loss: 0.0497 - val_mean_squared_error: 0.0497 - val_mean_absolute_error: 0.1916
# Epoch 22/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0530 - mean_squared_error: 0.0530 - mean_absolute_error: 0.1980 - val_loss: 0.0424 - val_mean_squared_error: 0.0424 - val_mean_absolute_error: 0.1749
# Epoch 23/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1900 - val_loss: 0.0425 - val_mean_squared_error: 0.0425 - val_mean_absolute_error: 0.1765
# Epoch 24/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0476 - mean_squared_error: 0.0476 - mean_absolute_error: 0.1823 - val_loss: 0.0697 - val_mean_squared_error: 0.0697 - val_mean_absolute_error: 0.1826
# Epoch 25/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0443 - mean_squared_error: 0.0443 - mean_absolute_error: 0.1761 - val_loss: 0.0379 - val_mean_squared_error: 0.0379 - val_mean_absolute_error: 0.1625
# Epoch 26/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0411 - mean_squared_error: 0.0411 - mean_absolute_error: 0.1709 - val_loss: 0.0414 - val_mean_squared_error: 0.0414 - val_mean_absolute_error: 0.1733
# Epoch 27/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0736 - mean_squared_error: 0.0736 - mean_absolute_error: 0.1820 - val_loss: 0.2652 - val_mean_squared_error: 0.2652 - val_mean_absolute_error: 0.3042
# Epoch 28/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1613 - val_loss: 0.0675 - val_mean_squared_error: 0.0675 - val_mean_absolute_error: 0.1640
# Epoch 29/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0434 - mean_squared_error: 0.0434 - mean_absolute_error: 0.1583 - val_loss: 0.8924 - val_mean_squared_error: 0.8924 - val_mean_absolute_error: 0.5641
# Epoch 30/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0519 - mean_squared_error: 0.0519 - mean_absolute_error: 0.1544 - val_loss: 0.1235 - val_mean_squared_error: 0.1235 - val_mean_absolute_error: 0.1979
# Epoch 31/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0390 - mean_squared_error: 0.0390 - mean_absolute_error: 0.1499 - val_loss: 0.0535 - val_mean_squared_error: 0.0535 - val_mean_absolute_error: 0.1509
# Epoch 32/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0370 - mean_squared_error: 0.0370 - mean_absolute_error: 0.1469 - val_loss: 0.0430 - val_mean_squared_error: 0.0430 - val_mean_absolute_error: 0.1425
# Epoch 33/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0329 - mean_squared_error: 0.0329 - mean_absolute_error: 0.1439 - val_loss: 0.0295 - val_mean_squared_error: 0.0295 - val_mean_absolute_error: 0.1377
# Epoch 34/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0303 - mean_squared_error: 0.0303 - mean_absolute_error: 0.1406 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1359
# Epoch 35/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0316 - mean_squared_error: 0.0316 - mean_absolute_error: 0.1390 - val_loss: 0.0327 - val_mean_squared_error: 0.0327 - val_mean_absolute_error: 0.1392
# Epoch 36/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0294 - mean_squared_error: 0.0294 - mean_absolute_error: 0.1346 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.1325
# Epoch 37/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0275 - mean_squared_error: 0.0275 - mean_absolute_error: 0.1320 - val_loss: 0.0256 - val_mean_squared_error: 0.0256 - val_mean_absolute_error: 0.1279
# Epoch 38/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1296 - val_loss: 0.0250 - val_mean_squared_error: 0.0250 - val_mean_absolute_error: 0.1256
# Epoch 39/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0256 - mean_squared_error: 0.0256 - mean_absolute_error: 0.1274 - val_loss: 0.0240 - val_mean_squared_error: 0.0240 - val_mean_absolute_error: 0.1214
# Epoch 40/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0249 - mean_squared_error: 0.0249 - mean_absolute_error: 0.1253 - val_loss: 0.0242 - val_mean_squared_error: 0.0242 - val_mean_absolute_error: 0.1233
# Epoch 41/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - mean_absolute_error: 0.1232 - val_loss: 0.0236 - val_mean_squared_error: 0.0236 - val_mean_absolute_error: 0.1212
# Epoch 42/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - mean_absolute_error: 0.1216 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - val_mean_absolute_error: 0.1270
# Epoch 43/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0289 - mean_squared_error: 0.0289 - mean_absolute_error: 0.1251 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1321
# Epoch 44/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0251 - mean_squared_error: 0.0251 - mean_absolute_error: 0.1211 - val_loss: 0.0239 - val_mean_squared_error: 0.0239 - val_mean_absolute_error: 0.1198
# Epoch 45/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0281 - mean_squared_error: 0.0281 - mean_absolute_error: 0.1208 - val_loss: 0.0404 - val_mean_squared_error: 0.0404 - val_mean_absolute_error: 0.1219
# Epoch 46/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0251 - mean_squared_error: 0.0251 - mean_absolute_error: 0.1180 - val_loss: 0.0239 - val_mean_squared_error: 0.0239 - val_mean_absolute_error: 0.1170
# Epoch 47/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - mean_absolute_error: 0.1159 - val_loss: 0.0225 - val_mean_squared_error: 0.0225 - val_mean_absolute_error: 0.1157
# Epoch 48/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - mean_absolute_error: 0.1141 - val_loss: 0.0220 - val_mean_squared_error: 0.0220 - val_mean_absolute_error: 0.1156
# Epoch 49/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - mean_absolute_error: 0.1134 - val_loss: 0.0232 - val_mean_squared_error: 0.0232 - val_mean_absolute_error: 0.1143
# Epoch 50/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0220 - mean_squared_error: 0.0220 - mean_absolute_error: 0.1110 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.1111
# Epoch 51/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0211 - mean_squared_error: 0.0211 - mean_absolute_error: 0.1098 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.1088
# Epoch 52/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0205 - mean_squared_error: 0.0205 - mean_absolute_error: 0.1088 - val_loss: 0.0199 - val_mean_squared_error: 0.0199 - val_mean_absolute_error: 0.1080
# Epoch 53/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0201 - mean_squared_error: 0.0201 - mean_absolute_error: 0.1077 - val_loss: 0.0197 - val_mean_squared_error: 0.0197 - val_mean_absolute_error: 0.1078
# Epoch 54/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0198 - mean_squared_error: 0.0198 - mean_absolute_error: 0.1069 - val_loss: 0.0194 - val_mean_squared_error: 0.0194 - val_mean_absolute_error: 0.1063
# Epoch 55/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0200 - mean_squared_error: 0.0200 - mean_absolute_error: 0.1071 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - val_mean_absolute_error: 0.1085
# Epoch 56/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0214 - mean_squared_error: 0.0214 - mean_absolute_error: 0.1078 - val_loss: 0.0200 - val_mean_squared_error: 0.0200 - val_mean_absolute_error: 0.1042
# Epoch 57/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0199 - mean_squared_error: 0.0199 - mean_absolute_error: 0.1054 - val_loss: 0.0195 - val_mean_squared_error: 0.0195 - val_mean_absolute_error: 0.1072
# Epoch 58/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0192 - mean_squared_error: 0.0192 - mean_absolute_error: 0.1040 - val_loss: 0.0191 - val_mean_squared_error: 0.0191 - val_mean_absolute_error: 0.1067
# Epoch 59/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - mean_absolute_error: 0.1032 - val_loss: 0.0188 - val_mean_squared_error: 0.0188 - val_mean_absolute_error: 0.1053
# Epoch 60/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0187 - mean_squared_error: 0.0187 - mean_absolute_error: 0.1025 - val_loss: 0.0184 - val_mean_squared_error: 0.0184 - val_mean_absolute_error: 0.1026
# Epoch 61/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - mean_absolute_error: 0.1017 - val_loss: 0.0182 - val_mean_squared_error: 0.0182 - val_mean_absolute_error: 0.1020
# Epoch 62/200
# 12059/12059 [==============================] - 20s 2ms/step - loss: 0.0203 - mean_squared_error: 0.0203 - mean_absolute_error: 0.1051 - val_loss: 0.0200 - val_mean_squared_error: 0.0200 - val_mean_absolute_error: 0.1019
# Epoch 63/200
# 10368/12059 [========================>.....] - ETA: 2s - loss: 0.0192 - mean_squared_error: 0.0192 - mean_absolute_error: 0.1029

# %%
samples = x_data[50:60]
save_images(model,samples)
